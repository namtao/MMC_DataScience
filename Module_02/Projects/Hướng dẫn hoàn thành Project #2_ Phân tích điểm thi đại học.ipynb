# %% [markdown]
# # Tổng quan

# %% [markdown]
# ## Giới thiệu

# %% [markdown]
# Dự án Phân tích điểm thi đại học nhằm mục đích thu thập và phân tích dữ liệu điểm thi đại học nhằm cung cấp thông tin hữu ích cho thí sinh, phụ huynh và các nhà hoạch định giáo dục. Dự án bao gồm hai giai đoạn chính: thu thập dữ liệu và phân tích dữ liệu.

# %% [markdown]
# ### Thu thập dữ liệu

# %% [markdown]
# Dữ liệu điểm thi đại học được thu thập từ nhiều nguồn khác nhau, bao gồm:
#
# * Website của các trường đại học
# * Website của Bộ Giáo dục và Đào tạo
# * Các trang báo điện tử uy tín
#
# Dữ liệu được thu thập một cách tự động bằng Python và thư viện. Các công cụ crawl web được sử dụng để truy cập các trang web có chứa dữ liệu điểm thi và trích xuất thông tin cần thiết một cách hiệu quả.

# %% [markdown]
# ### Phân tích dữ liệu

# %% [markdown]
# Dữ liệu điểm thi sau khi được thu thập sẽ được phân tích bằng các phương pháp thống kê và học máy. Các phương pháp phân tích dữ liệu được sử dụng bao gồm:
#
# * Phân tích mô tả: Mô tả các đặc điểm cơ bản của dữ liệu điểm thi, chẳng hạn như phân bố điểm, điểm trung bình, điểm cao nhất, điểm thấp nhất, v.v.
# * Phân tích so sánh: So sánh điểm thi của các thí sinh theo các tiêu chí khác nhau, chẳng hạn như khu vực, trường thi, khối thi, môn thi, v.v.
# * Phân tích dự đoán: Dự đoán điểm thi của thí sinh trong các kỳ thi sắp tới dựa trên dữ liệu điểm thi của các kỳ thi trước.

# %% [markdown]
# ### Kết quả

# %% [markdown]
# Kết quả phân tích dữ liệu điểm thi đại học sẽ được trình bày dưới dạng báo cáo, biểu đồ, đồ thị và các hình ảnh trực quan khác. Các kết quả này sẽ cung cấp thông tin hữu ích cho thí sinh, phụ huynh và các nhà hoạch định giáo dục.

# %% [markdown]
# Dự án Phân tích điểm thi đại học mang lại nhiều lợi ích cho cộng đồng, bao gồm:
#
# * Cung cấp thông tin hữu ích cho thí sinh: Giúp thí sinh đánh giá năng lực bản thân, lựa chọn nguyện vọng thi phù hợp và có kế hoạch ôn thi hiệu quả.
# * Hỗ trợ phụ huynh: Giúp phụ huynh định hướng cho con em mình trong việc lựa chọn ngành học và trường đại học phù hợp.
# * Cung cấp dữ liệu cho các nhà hoạch định giáo dục: Giúp các nhà hoạch định giáo dục đánh giá chất lượng giáo dục, đưa ra các chính sách giáo dục phù hợp và nâng cao hiệu quả tuyển sinh đại học.

# %% [markdown]
# # Hướng dẫn thu thập dữ liệu điểm thi đại học

# %% [markdown]
# Tính đến thời điểm hiện tại, chuẩn bị sắp tới kỳ thi THPT Quốc Gia 2024 nên một số trang không còn lưu trữ dữ liệu của năm trước. Tiêu chí tìm kiếm trang sẽ là một trang website công bố điểm thi uy tín, không có captra khi nhập số báo danh.
#
# Sau khi tìm kiếm một lượt, ta thấy trang https://diemthi.vnanet.vn của vnanet rất phù hợp ==> quất luôn trang này để crawl dữ liệu

# %% [markdown]
# ## Chuẩn bị môi trường

# %% [markdown]
# Bước đầu tiên là cài đặt Python và các thư viện cần thiết. Bạn có thể sử dụng pip, trình quản lý gói của Python, để cài đặt:
# * requests: Thư viện mạnh mẽ cho việc gửi yêu cầu HTTP đến server.
# * pandas: Thư viện thao tác và phân tích dữ liệu dạng bảng, cung cấp cấu trúc DataFrame linh hoạt.

# %%
# %pip install requests
# %pip install pandas
# Out:
# Requirement already satisfied: requests in c:\projects\mmc_datascience\.conda\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\projects\mmc_datascience\.conda\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\projects\mmc_datascience\.conda\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\projects\mmc_datascience\.conda\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\projects\mmc_datascience\.conda\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\projects\mmc_datascience\.conda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\projects\mmc_datascience\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import thư viện

# %% [markdown]
# * requests: Thư viện để thực hiện yêu cầu HTTP đến API.
# * time: Thư viện để điều khiển thời gian, dùng để tạo độ trễ giữa các yêu cầu.
# * pandas: Thư viện để thao tác dữ liệu với DataFrame.
# * os: Thư viện để tương tác với hệ điều hành, dùng để kiểm tra sự tồn tại của file.

# %%
import requests
import time
import pandas as pd
import os

# %% [markdown]
# ## Xây dựng danh sách mã tỉnh

# %% [markdown]
# Hiện tại mã số của thí sinh dự thi sẽ có dạng AABBBBBB trong đó AA là mã tỉnh, BBBBBB là mã thí sinh.
#
# Tính đến thời điểm năm 2023, Việt Nam có 64 tỉnh, vậy AA sẽ bắt đầu từ 01 và kết thúc là 64. Tìm hiểu trên Google, ta thấy có trang https://diemthi.beecost.vn/
#  và https://diemthi.vnanet.vn/ có API để lấy được dữ liệu chung trong toàn tỉnh. Ta nhập test thử với SBD là 01000001 và ra kết quả
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Để ý thì api này có header Access-Control-Allow-Origin = * . Quá ngon luôn
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tìm hiểu cấu trúc của API, ta thấy có 1 tham số truyền vào là id
#
# https://api-university-2022.beecost.vn/university/lookup_examiner?id=01000001
#
# Trong đó, ta thấy có thông tin để lấy đc tên của Sở GD thông qua trường test_location:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ta sẽ sử dụng hàm get data bằng thư viện requests. Dữ liệu truyền vào là đường dẫn, và đầu ra là kết quả crawl được (mã 200 là oke)

# %%
response = requests.get("https://api-university-2022.beecost.vn/university/lookup_examiner?id=01000001")
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Ta sử dụng hàm json để chuyển nó về dạng json rồi lưu vào biến data

# %%
data = response.json()
print(data)
# Out:
# {'status': 'success', 'data': {'scores': {'id': 1000001, 'mathematics_score': 8.4, 'physics_score': None, 'chemistry_score': None, 'foreign_language_score': 9.2, 'foreign_language_type': 'N1', 'english_score': 9.2, 'russian_score': None, 'french_score': None, 'chinese_score': None, 'german_score': None, 'japanese_score': None, 'biology_score': None, 'literature_score': 8.5, 'history_score': 6.75, 'geography_score': 6.0, 'civic_education_score': 9.0, 'year': '2023', 'subject_group_score': {'A07': 21.15, 'A08': 24.15, 'A09': 23.4, 'C00': 21.25, 'C03': 23.65, 'C04': 22.9, 'C14': 25.9, 'C15': 24.15, 'C19': 24.25, 'C20': 23.5, 'D01': 26.1, 'D09': 24.35, 'D10': 23.6, 'D14': 24.45, 'D15': 23.7, 'D66': 26.7, 'D78': 24.95, 'D84': 26.6, 'D96': 24.85}, 'korean_score': None}, 'equivalent_scores': {'mathematics_score': 8.8, 'english_score': 9.2, 'literature_score': 8.08, 'history_score': 7.25, 'geography_score': 6.75, 'civic_education_score': 8.75, 'subject_group_score': {'A07': 22.8, 'A08': 24.8, 'A09': 24.3, 'C00': 22.08, 'C03': 24.13, 'C04': 23.63, 'C14': 25.63, 'C15': 24.46, 'C19': 24.08, 'C20': 23.58, 'D01': 26.08, 'D09': 25.25, 'D10': 24.75, 'D14': 24.53, 'D15': 24.03, 'D66': 26.03, 'D78': 24.86, 'D84': 26.75, 'D96': 25.58}}, 'equivalent_scores_2020': {'mathematics_score': 9.0, 'english_score': 9.8, 'literature_score': 8.08, 'history_score': 5.75, 'geography_score': 7.0, 'civic_education_score': 9.25, 'subject_group_score': {'A07': 21.75, 'A08': 24.0, 'A09': 25.25, 'C00': 20.83, 'C03': 22.83, 'C04': 24.08, 'C14': 26.33, 'C15': 24.41, 'C19': 23.08, 'C20': 24.33, 'D01': 26.88, 'D09': 24.55, 'D10': 25.8, 'D14': 23.63, 'D15': 24.88, 'D66': 27.13, 'D78': 25.21, 'D84': 28.05, 'D96': 26.13}}, 'equivalent_group_scores': {'A07': 22.4, 'A08': 24.35, 'A09': 23.95, 'C00': 21.8, 'C03': 23.92, 'C04': 23.46, 'C14': 25.51, 'C15': 24.32, 'C19': 23.8, 'C20': 23.33, 'D01': 25.97, 'D09': 24.7, 'D10': 24.2, 'D14': 24.28, 'D15': 23.77, 'D66': 25.86, 'D78': 24.66, 'D84': 26.25, 'D96': 25.05}, 'equivalent_group_scores_2020': {'A07': 21.45, 'A08': 23.7, 'A09': 24.65, 'C00': 20.52, 'C03': 22.86, 'C04': 23.66, 'C14': 25.86, 'C15': 24.08, 'C19': 22.8, 'C20': 24.02, 'D01': 26.62, 'D09': 24.6, 'D10': 25.4, 'D14': 24.02, 'D15': 24.92, 'D66': 26.92, 'D78': 25.27, 'D84': 27.45, 'D96': 25.75}, 'subject_group_score_statistic': {'A07': {'score': 21.15, 'subject_group_name': 'A07', 'greater': 118453, 'equal': 2626, 'lower': 547221, 'total': 668301}, 'A08': {'score': 24.15, 'subject_group_name': 'A08', 'greater': 70789, 'equal': 2278, 'lower': 491423, 'total': 564491}, 'A09': {'score': 23.4, 'subject_group_name': 'A09', 'greater': 90192, 'equal': 2904, 'lower': 471404, 'total': 564501}, 'C00': {'score': 21.25, 'subject_group_name': 'C00', 'greater': 167434, 'equal': 16043, 'lower': 498223, 'total': 681701}, 'C03': {'score': 23.65, 'subject_group_name': 'C03', 'greater': 48322, 'equal': 1755, 'lower': 619595, 'total': 669673}, 'C04': {'score': 22.9, 'subject_group_name': 'C04', 'greater': 62031, 'equal': 2180, 'lower': 604138, 'total': 668350}, 'C14': {'score': 25.9, 'subject_group_name': 'C14', 'greater': 24513, 'equal': 1500, 'lower': 538486, 'total': 564500}, 'C15': {'score': 24.15, 'subject_group_name': 'C15', 'greater': 41021, 'equal': 654, 'lower': 522738, 'total': 564414}, 'C19': {'score': 24.25, 'subject_group_name': 'C19', 'greater': 110179, 'equal': 13848, 'lower': 441167, 'total': 565195}, 'C20': {'score': 23.5, 'subject_group_name': 'C20', 'greater': 139868, 'equal': 17865, 'lower': 407499, 'total': 565233}, 'D01': {'score': 26.1, 'subject_group_name': 'D01', 'greater': 11084, 'equal': 740, 'lower': 861279, 'total': 873104}, 'D09': {'score': 24.35, 'subject_group_name': 'D09', 'greater': 16781, 'equal': 686, 'lower': 539714, 'total': 557182}, 'D10': {'score': 23.6, 'subject_group_name': 'D10', 'greater': 21395, 'equal': 767, 'lower': 534907, 'total': 557070}, 'D14': {'score': 24.45, 'subject_group_name': 'D14', 'greater': 28244, 'equal': 951, 'lower': 528193,  ...

# %% [markdown]
# Ta thấy có khóa "test_location" chính là lưu thông tin các Sở GDĐT và nằm trong khóa "data" nên sử dụng hàm get lấy giá trị

# %%
# print(data["data"].get("scores"))
print(data.get("data").get("scores"))
# Out:
# {'id': 1000001, 'mathematics_score': 8.4, 'physics_score': None, 'chemistry_score': None, 'foreign_language_score': 9.2, 'foreign_language_type': 'N1', 'english_score': 9.2, 'russian_score': None, 'french_score': None, 'chinese_score': None, 'german_score': None, 'japanese_score': None, 'biology_score': None, 'literature_score': 8.5, 'history_score': 6.75, 'geography_score': 6.0, 'civic_education_score': 9.0, 'year': '2023', 'subject_group_score': {'A07': 21.15, 'A08': 24.15, 'A09': 23.4, 'C00': 21.25, 'C03': 23.65, 'C04': 22.9, 'C14': 25.9, 'C15': 24.15, 'C19': 24.25, 'C20': 23.5, 'D01': 26.1, 'D09': 24.35, 'D10': 23.6, 'D14': 24.45, 'D15': 23.7, 'D66': 26.7, 'D78': 24.95, 'D84': 26.6, 'D96': 24.85}, 'korean_score': None}

# %% [markdown]
# Hoàn thiện hàm lấy mã tỉnh với id test là `01000001` . Ta được kết quả là Sở GDĐT Hà Nội

# %%
def getLocation():
    try:
        response = requests.get("https://api-university-2022.beecost.vn/university/lookup_examiner?id=01000001")
        data = response.json()
        if data and data.get("data"):
            test_location = data["data"].get("test_location")
            return test_location
    except Exception as e:
        print("Error:", e)

print(getLocation())
# Out:
# Sở GDĐT Hà Nội

# %% [markdown]
# Vì mã tỉnh bắt đầu từ 01 tới 64, nên ta chỉ cần tạo một vòng lặp để lấy từng tên của các Sở GD tỉnh và lưu vào biến result có dạng là Dictionary.

# %%
def get_test_location(id):
    try:
        response = requests.get(f"https://api-university-2022.beecost.vn/university/lookup_examiner?id={id}")
        data = response.json()
        if data and data.get("data"):
            test_location = data["data"].get("test_location")
            return test_location
    except Exception as e:
        print("Error:", e)

cities = {}
for i in range(1, 65):
    id = str(i).zfill(2) + "000001"  # Convert the integer to a string and pad with 0 on the left if necessary
    location_name = get_test_location(id)
    if location_name:
        cities[location_name] = id

print(cities)
# Out:
# {'Sở GDĐT Hà Nội': '01000001', 'Sở GDĐT TP. Hồ Chí Minh': '02000001', 'Sở GDĐT Hải Phòng': '03000001', 'Sở GDĐT Đà Nẵng': '04000001', 'Sở GDĐT Hà Giang': '05000001', 'Sở GDĐT Cao Bằng': '06000001', 'Sở GDĐT Lai Châu': '07000001', 'Sở GDĐT Lào Cai': '08000001', 'Sở GDĐT Tuyên Quang': '09000001', 'Sở GDĐT Lạng Sơn': '10000001', 'Sở GDĐT Bắc Kạn': '11000001', 'Sở GDĐT Thái Nguyên': '12000001', 'Sở GDĐT Yên Bái': '13000001', 'Sở GDĐT Sơn La': '14000001', 'Sở GDĐT Phú Thọ': '15000001', 'Sở GDĐT Vĩnh Phúc': '16000001', 'Sở GDĐT Quảng Ninh': '17000001', 'Sở GDĐT Bắc Giang': '18000001', 'Sở GDĐT Bắc Ninh': '19000001', 'Sở GDĐT Hải Dương': '21000001', 'Sở GDĐT Hưng Yên': '22000001', 'Sở GDĐT Hoà Bình': '23000001', 'Sở GDĐT Hà Nam': '24000001', 'Sở GDĐT Nam Định': '25000001', 'Sở GDĐT Thái Bình': '26000001', 'Sở GDĐT Ninh Bình': '27000001', 'Sở GDĐT Thanh Hoá': '28000001', 'Sở GDĐT Nghệ An': '29000001', 'Sở GDĐT Hà Tĩnh': '30000001', 'Sở GDĐT Quảng Bình': '31000001', 'Sở GDĐT Quảng Trị': '32000001', 'Sở GDĐT Thừa Thiên -Huế': '33000001', 'Sở GDĐT Quảng Nam': '34000001', 'Sở GDĐT Quảng Ngãi': '35000001', 'Sở GDĐT Kon Tum': '36000001', 'Sở GDĐT Bình Định': '37000001', 'Sở GDĐT Gia Lai': '38000001', 'Sở GDĐT Phú Yên': '39000001', 'Sở GDĐT Đắk Lắk': '40000001', 'Sở GDĐT Khánh Hoà': '41000001', 'Sở GDĐT Lâm Đồng': '42000001', 'Sở GDĐT Bình Phước': '43000001', 'Sở GDĐT Bình Dương': '44000001', 'Sở GDĐT Ninh Thuận': '45000001', 'Sở GDĐT Tây Ninh': '46000001', 'Sở GDĐT Bình Thuận': '47000001', 'Sở GDĐT Đồng Nai': '48000001', 'Sở GDĐT Long An': '49000001', 'Sở GDĐT Đồng Tháp': '50000001', 'Sở GDĐT An Giang': '51000001', 'Sở GDĐT Bà Rịa-Vũng Tàu': '52000001', 'Sở GDĐT Tiền Giang': '53000001', 'Sở GDĐT Kiên Giang': '54000001', 'Sở GDĐT Cần Thơ': '55000001', 'Sở GDĐT Bến Tre': '56000001', 'Sở GDĐT Vĩnh Long': '57000001', 'Sở GDĐT Trà Vinh': '58000001', 'Sở GDĐT Sóc Trăng': '59000001', 'Sở GDĐT Bạc Liêu': '60000001', 'Sở GDĐT Cà Mau': '61000001', 'Sở GDĐT Điện Biên': '62000001', 'Sở GDĐT Đăk Nông': '63000001', 'Sở GDĐT Hậu Giang': '64000001'}

# %% [markdown]
# ## Xây dựng đoạn code crawl dữ liệu

# %% [markdown]
# **Khởi tạo DataFrame:**
#
# ```python
# df = pd.DataFrame()
# ```
#
# * **`df`:** Khởi tạo một DataFrame rỗng để lưu trữ dữ liệu thu thập được từ API.
#
# **Kiểm tra sự tồn tại của file CSV:**
#
# ```python
# file_exists = os.path.isfile('./Data/data.csv')
# ```
#
# * **`file_exists`:** Kiểm tra xem file CSV có tồn tại trong thư mục `./Data/` chưa. Nếu file chưa tồn tại, biến `file_exists` sẽ là `False`.
#
# **Vòng lặp thu thập dữ liệu:**
#
# ```python
# for city, start_code in cities.items():
#     code = int(start_code)
#     while True:
#         # ... logic thu thập dữ liệu ...
# ```
#
# * **`for city, start_code in cities.items():`:** Vòng lặp `for` duyệt qua từng phần tử (key, value) trong dictionary `cities`. `city` là tên thành phố, `start_code` là mã số của trường bắt đầu cho thành phố đó.
# * **`code = int(start_code)`:** Chuyển đổi mã số `start_code` (kiểu chuỗi) thành kiểu số nguyên.
# * **`while True`:** Vòng lặp vô hạn, sẽ tiếp tục chạy cho đến khi gặp điều kiện dừng.
#
# **Thu thập dữ liệu từ API:**
#
# ```python
# url = f"https://api-university-2022.beecost.vn/university/lookup_examiner?id={str(code).zfill(8)}"
# try:
#     response = requests.get(url)
#     data = response.json()
#
#     if not data or 'error' in data:
#         # Bỏ qua mã số lỗi, tăng mã và tiếp tục
#         code += 1
#         continue
#
#     # Trích xuất "scores" and "test_location"
#     scores = data['data']['scores']
#     test_location = data['data']['test_location']
#
#     # Thêm 'test_location' vào dictionary "scores"
#     scores['test_location'] = test_location
#
#     # Tạo DataFrame từ dữ liệu
#     flat_data = pd.DataFrame([scores])
#
#     # Lấy header từ DataFrame đầu tiên nếu file chưa tồn tại
#     if not file_exists and not flat_data.empty:
#         header = flat_data.columns.tolist()
#         flat_data.to_csv('./Data/data.csv', mode='w', header=header, index=False)  # Ghi với mode='w' để ghi đè
#         file_exists = True
#     else:
#         # Ghi dữ liệu vào file CSV (không có header)
#         flat_data.to_csv('./Data/data.csv', mode='a', header=False, index=False)
#
#     print(flat_data)
#     code += 1
#     time.sleep(0.1)
#
# except Exception as e:
#     # Ghi log lỗi và tăng mã
#     print(f"Lỗi khi lấy dữ liệu cho mã {code}: {e}")
#     code += 1
#     time.sleep(0.1)
# ```
#
# * **`url = f"https://api-university-2022.beecost.vn/university/lookup_examiner?id={str(code).zfill(8)}"`:** Tạo URL yêu cầu API bằng cách kết hợp địa chỉ API, mã trường `code` (đã được chuyển đổi thành chuỗi và thêm các ký tự "0" ở đầu để đảm bảo độ dài 8 chữ số), và dấu "?" để phân tách.
# * **`try: ... except Exception as e:`:**  Khối `try` để thực hiện yêu cầu API, khối `except` xử lý lỗi nếu xảy ra trong quá trình thực hiện.
# * **`response = requests.get(url)`:** Gửi yêu cầu HTTP GET đến API được xác định bởi URL.
# * **`data = response.json()`:** Chuyển đổi phản hồi JSON từ API thành một dictionary Python.
# * **`if not data or 'error' in data`:** Kiểm tra xem phản hồi từ API có thành công hay không. Nếu không có dữ liệu (`not data`) hoặc có lỗi (`'error' in data`) thì bỏ qua mã số này.
# * **`scores = data['data']['scores']`:** Trích xuất dữ liệu về điểm thi (`scores`) từ dictionary `data`.
# * **`test_location = data['data']['test_location']`:** Trích xuất dữ liệu về địa điểm thi (`test_location`) từ dictionary `data`.
# * **`scores['test_location'] = test_location`:** Thêm thông tin về địa điểm thi vào dictionary `scores`.
# * **`flat_data = pd.DataFrame([scores])`:** Tạo DataFrame `flat_data` từ dữ liệu `scores`.
# * **`flat_data.to_csv('./Data/data.csv', mode='w', header=header, index=False)`:** Ghi DataFrame `flat_data` vào file CSV với header (nếu chưa có).
# * **`flat_data.to_csv('./Data/data.csv', mode='a', header=False, index=False)`:** Ghi DataFrame `flat_data` vào file CSV (không có header).
# * **`code += 1`:** Tăng mã trường `code` lên 1 đơn vị để truy vấn dữ liệu của trường tiếp theo.
# * **`time.sleep(0.1)`:** Tạo độ trễ 0.1 giây để tránh quá tải API.
# * **`print(flat_data)`:** In DataFrame `flat_data` ra màn hình để kiểm tra.
#
# **Xử lý lỗi:**
#
# ```python
# except Exception as e:
#     # Ghi log lỗi và tăng mã
#     print(f"Lỗi khi lấy dữ liệu cho mã {code}: {e}")
#     code += 1
#     time.sleep(0.1)
# ```
#
# * **`except Exception as e:`:**  Xử lý bất kỳ lỗi nào xảy ra trong quá trình thực hiện.
# * **`print(f"Lỗi khi lấy dữ liệu cho mã {code}: {e}")`:** Ghi log lỗi vào console, bao gồm mã trường và thông tin lỗi.
# * **`code += 1`:** Tăng mã trường `code` lên 1 đơn vị để tiếp tục.
# * **`time.sleep(0.1)`:** Tạo độ trễ 0.1 giây để tránh quá tải API.

# %% [markdown]
# Dưới đây là mã code đầy đủ:
# * Lưu ý: Vì dữ liệu crawl về rất lớn nên nó sẽ chạy rất lâu. Vậy nên trong hướng dẫn này, mình đã crawl dữ liệu về cho mọi người rồi. Học phần này để biết thôi :))

# %%
os.makedirs("Data", exist_ok=True)

df = pd.DataFrame()

# Kiểm tra file CSV
file_exists = os.path.isfile("./data/data.csv")

for city, start_code in cities.items():
    code = int(start_code)
    while True:
        url = f"https://api-university-2022.beecost.vn/university/lookup_examiner?id={str(code).zfill(8)}"
        try:
            response = requests.get(url)
            data = response.json()

            if not data or "error" in data:
                # Bỏ qua mã số lỗi, tăng mã và tiếp tục
                code += 1
                continue

            # Trích xuất "scores" and "test_location"
            scores = data["data"]["scores"]
            test_location = data["data"]["test_location"]

            # Thêm 'test_location' vào dictionary "scores"
            scores["test_location"] = test_location

            # Tạo DataFrame từ dữ liệu
            flat_data = pd.DataFrame([scores])

            # Lấy header từ DataFrame đầu tiên nếu file chưa tồn tại
            if not file_exists and not flat_data.empty:
                header = flat_data.columns.tolist()
                flat_data.to_csv(
                    "./data/data.csv", mode="w", header=header, index=False
                )  # Ghi với mode='w' để ghi đè
                file_exists = True
            else:
                # Ghi dữ liệu vào file CSV (không có header)
                flat_data.to_csv("./data/data.csv", mode="a", header=False, index=False)

            print(flat_data)
            code += 1
            time.sleep(0.1)

        except Exception as e:
            # Ghi log lỗi và tăng mã
            print(f"Lỗi khi lấy dữ liệu cho mã {code}: {e}")
            code += 1
            time.sleep(0.1)
# Out:
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000001                8.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           6.75              6.0                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.15, 'A08': 24.15, 'A09': 23.4, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000002                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           8.75              6.5                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 22.45, 'A08': 24.45, 'A09': 22.2, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000003              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              6.5           9.25              7.5                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023      {'C00': 23.25}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000004                7.8          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.8                    N1            7.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25            4.5             6.25                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.55, 'A08': 20.55, 'A09': 22.3, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000005                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.8                    N1            7.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           4.75             6.75                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.7, 'A08': 20.2, 'A09': 22.2, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000006                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             9.25            8.5             7.25                   9.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 23.35, 'A08': 25.85, 'A09': 24.6, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000007                5.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     6.4                    N1            6.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              7.0           4.75             5.75                    8.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 16.1, 'A08': 18.35, 'A09': 19.35, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000008                7.2            5.0              3.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     6.0                    N1            6.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          1.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               7.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 15.7, 'A01': 18.2, 'A02': 13.95, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000009                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25            6.5             7.25                    9.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.35, 'A08': 23.6, 'A09': 24.35, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000010                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.0                    N1            7.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.5           7.25              6.5                   8.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.95, 'A08': 24.2, 'A09': 23.45, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000011                5.6           5.75              3.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.4                    N1            8.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           4.5
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               7.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 14.85, 'A01': 19.75, 'A02': 15.85, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000012                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.4                    N1            8.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5            8.0             7.75                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 22.95, 'A08': 23.45, 'A09': 23.2, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000013                7.4            8.0             3.75
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.0                    N1            8.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          5.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              5.75           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 19.15, 'A01': 23.4, 'A02': 21.15, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000014                7.0          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              4.5           4.25              6.5                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.75, 'A08': 19.5, 'A09': 21.75, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000015                8.2           5.75              7.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          7.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               8.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 21.45, 'A01': 23.15, 'A02': 21.7, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000016                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.4                    N1            8.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75            6.5             6.25                    9.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.95, 'A08': 24.2, 'A09': 23.95, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000017                7.4            3.0              6.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     6.6                    N1            6.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          6.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              7.75           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 16.9, 'A01': 17.0, 'A02': 17.15, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000018              None          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     2.8                    N1            2.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              7.0            7.5             7.25                   None
#
#    year                        subject_group_score korean_score  \
# 0  2023  {'C00': 21.75, 'D14': 17.3, 'D15': 17.05}         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000019                8.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0           8.25             7.25                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 23.9, 'A08': 25.15, 'A09': 24.15, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000020                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.2                    N1            7.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75           8.75              9.0                   9.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 25.95, 'A08': 26.7, 'A09': 26.95, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000021                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.8                    N1            7.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25           5.75              6.5                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.45, 'A08': 22.2, 'A09': 22.95, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000022                8.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             9.25            6.5              6.5                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.0, 'A08': 23.75, 'A09': 23.75, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000023                8.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.8                    N1            9.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           8.75              7.5                   8.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 24.85, 'A08': 26.1, 'A09': 24.85, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000024                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.6                    N1            9.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0           8.75             7.25                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 24.2, 'A08': 26.2, 'A09': 24.7, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000025                6.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.0                    N1            8.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25           6.25              6.5                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.35, 'A08': 21.1, 'A09': 21.35, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000026                7.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0           5.25              6.0                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.65, 'A08': 21.15, 'A09': 21.9, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000027                8.0            5.0              8.0
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           8.0
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               8.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 21.0, 'A01': 22.2, 'A02': 21.0, 'A16':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000028                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.6                    N1            9.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0           6.25             7.75                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 22.2, 'A08': 23.7, 'A09': 25.2, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000029                2.8          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             6.75           5.25             5.75                   None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 13.8, 'C00': 17.75, 'C03': 14.8, 'C04'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000030                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.6                    N1            8.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75            8.0             5.75                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.95, 'A08': 24.2, 'A09': 21.95, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
# Lỗi khi lấy dữ liệu cho mã 1000031: Expecting value: line 1 column 1 (char 0)
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000032                8.2           8.25             7.75
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     5.4                    N1            5.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          6.25
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              6.25           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 24.2, 'A01': 21.85, 'A02': 22.7, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000033                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0            5.0             5.25                    7.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.45, 'A08': 19.2, 'A09': 19.45, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000034                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     6.6                    N1            6.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0            7.0              6.5                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.1, 'A08': 23.1, 'A09': 22.6, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000035                5.0          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              3.5            4.5              5.5                   None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 15.0, 'C00': 13.5, 'C03': 13.0, 'C04':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000036                7.8           6.25              6.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     5.0                    N1            5.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           6.5
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              7.75           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 20.55, 'A01': 19.05, 'A02': 20.55, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000037              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           9.25             9.25                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023       {'C00': 27.0}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000038                7.8           7.75             7.25
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          7.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               8.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 22.8, 'A01': 24.75, 'A02': 23.3, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000039                5.8          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             9.25            6.0              7.0                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.8, 'A08': 21.05, 'A09': 22.05, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000040                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.6                    N1            8.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           5.25              6.5                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.95, 'A08': 21.45, 'A09': 22.7, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000041                8.6            6.0              8.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          8.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              7.75           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 23.1, 'A01': 24.0, 'A02': 23.35, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000042                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.4                    N1            7.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.5           6.75             5.25                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.6, 'A08': 22.6, 'A09': 21.1, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000043                7.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.6                    N1            7.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           7.25             5.25                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.5, 'A08': 22.5, 'A09': 20.5, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000044                7.6           7.25              8.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     6.2                    N1            6.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           5.5
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               6.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 23.35, 'A01': 21.05, 'A02': 20.35, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000045                3.8          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     4.2                    N1            4.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              7.5            6.5              5.5                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 15.8, 'A08': 18.55, 'A09': 17.55, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000046                7.8           6.75              7.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           6.5
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               4.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 22.05, 'A01': 23.95, 'A02': 21.05, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000047                8.6           7.75              5.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.6                    N1            8.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           4.0
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               7.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 21.85, 'A01': 24.95, 'A02': 20.35, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000048                5.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.4                    N1            7.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0            4.0             5.25                    7.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 14.65, 'A08': 16.4, 'A09': 17.65, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000049                7.8          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.0                    N1            8.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75           7.25              5.5                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.55, 'A08': 24.05, 'A09': 22.3, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000050                8.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.2                    N1            8.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           6.75             5.75                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.1, 'A08': 23.6, 'A09': 22.6, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000051                8.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75           7.25              6.5                   8.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 22.35, 'A08': 24.6, 'A09': 23.85, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000052                7.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.2                    N1            8.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.0           6.75             6.75                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.9, 'A08': 23.15, 'A09': 23.15, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000053                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5            4.5              6.5                   9.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.2, 'A08': 22.45, 'A09': 24.45, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000054              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             6.25           5.75             6.25                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023      {'C00': 18.25}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000055                7.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.0                    N1            7.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25            8.0              7.5                   9.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 22.5, 'A08': 24.75, 'A09': 24.25, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000056                6.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.4                    N1            7.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           6.75             5.25                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.0, 'A08': 21.0, 'A09': 19.5, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000057                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             9.25           6.25              6.0                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.85, 'A08': 23.1, 'A09': 22.85, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000058                7.8           6.75              8.0
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.4                    N1            7.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          4.75
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               5.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 22.55, 'A01': 21.95, 'A02': 19.3, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000059                8.2           6.75              5.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          8.25
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               8.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 20.45, 'A01': 23.75, 'A02': 23.2, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000060                6.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.0                    N1            8.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              7.5            5.5              5.5                    6.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.0, 'A08': 18.0, 'A09': 18.0, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000061              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             6.75           7.75             7.25                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023      {'C00': 21.75}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000062                6.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     5.4                    N1            5.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score geography_score civic_education_score  year  \
# 0              4.0           None            None                  None  2023
#
#   subject_group_score korean_score   test_location
# 0       {'D01': 15.8}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# ...
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              7.25           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 19.3, 'A02': 20.3, 'A16': 21.72, 'B00'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000277                7.4            5.0             7.25
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.0                    N1            8.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           5.5
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               6.0           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 19.65, 'A01': 20.4, 'A02': 17.9, 'A16'...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000278                7.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             9.25            7.0             7.25                    9.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.65, 'A08': 23.4, 'A09': 23.65, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000279                8.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              9.5           5.25              5.0                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 18.85, 'A08': 22.35, 'A09': 22.1, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000280                7.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             7.25           6.75              5.5                   9.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.65, 'A08': 23.4, 'A09': 22.15, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000281                5.6          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              7.0            7.0             7.25                   None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 19.85, 'C00': 21.25, 'C03': 19.6, 'C04...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000282                6.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.6                    N1            8.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25            5.0             6.75                    7.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.95, 'A08': 18.7, 'A09': 20.45, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000283              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           9.25             8.25                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023       {'C00': 25.5}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000284                6.8          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     7.8                    N1            7.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           4.75              5.5                   6.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.05, 'A08': 18.3, 'A09': 19.05, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id mathematics_score physics_score chemistry_score  \
# 0  1000285              None          None            None
#
#   foreign_language_score foreign_language_type english_score russian_score  \
# 0                   None                                None          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25            9.0              8.5                   None
#
#    year subject_group_score korean_score   test_location
# 0  2023      {'C00': 25.75}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000286                6.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.4                    N1            8.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5            7.0             6.75                    8.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.35, 'A08': 22.1, 'A09': 21.85, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000287                8.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.0           6.75             5.75                   8.25
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 20.7, 'A08': 23.2, 'A09': 22.2, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000288                8.8           8.75              8.0
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.2                    N1            8.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          6.25
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               7.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 25.55, 'A01': 25.75, 'A02': 23.8, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000289                8.8           8.75              5.0
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.4                    N1            8.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          5.25
#
#    literature_score  history_score geography_score civic_education_score  \
# 0               6.5           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 22.55, 'A01': 25.95, 'A02': 22.8, 'A16...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000290                7.6           8.75              3.5
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.6                    N1            9.6          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           7.0
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              6.25           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 19.85, 'A01': 25.95, 'A02': 23.35, 'A1...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000291                7.6          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.2                    N1            9.2          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0              8.5           8.75             6.75                    9.5
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 23.1, 'A08': 25.85, 'A09': 23.85, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000292                6.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     4.0                    N1            4.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             5.75            6.0              5.0                   6.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 17.2, 'A08': 18.95, 'A09': 17.95, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000293                5.0          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     5.4                    N1            5.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score geography_score civic_education_score  year  \
# 0             6.75           None            None                  None  2023
#
#   subject_group_score korean_score   test_location
# 0      {'D01': 17.15}         None  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000294                7.2          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     8.8                    N1            8.8          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.25           6.25             7.75                   7.75
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 21.2, 'A08': 21.2, 'A09': 22.7, 'C00':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score  physics_score  chemistry_score  \
# 0  1000295                8.4            8.5              6.0
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.0                    N1            9.0          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None           6.0
#
#    literature_score  history_score geography_score civic_education_score  \
# 0              7.25           None            None                  None
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A00': 22.9, 'A01': 25.9, 'A02': 22.9, 'A16':...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]
#         id  mathematics_score physics_score chemistry_score  \
# 0  1000296                8.4          None            None
#
#    foreign_language_score foreign_language_type  english_score russian_score  \
# 0                     9.4                    N1            9.4          None
#
#   french_score chinese_score  ... japanese_score biology_score  \
# 0         None          None  ...           None          None
#
#   literature_score  history_score  geography_score  civic_education_score  \
# 0             8.75            9.0             5.75                   10.0
#
#    year                                subject_group_score korean_score  \
# 0  2023  {'A07': 23.15, 'A08': 27.4, 'A09': 24.15, 'C00...         None
#
#     test_location
# 0  Sở GDĐT Hà Nội
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Phân tích điểm thi đại học

# %% [markdown]
# Import dữ liệu

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Đầu tiên, bạn hãy tải dữ liệu của mình sau khi đã crawl về

# %%
# %pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in c:\projects\mmc_datascience\.conda\lib\site-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in c:\projects\mmc_datascience\.conda\lib\site-packages (from gdown) (2.32.3)
# Collecting tqdm (from gdown)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      -------------------------------------- 57.6/57.6 kB 751.0 kB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests[socks]->gdown) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\projects\mmc_datascience\.conda\lib\site-packages (from requests[socks]->gdown) (2024.6.2)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\projects\mmc_datascience\.conda\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    --------------------------------- ------ 122.9/147.9 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 147.9/147.9 kB 2.9 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.3 MB/s eta 0:00:00
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: tqdm, soupsieve, PySocks, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.12.3 gdown-5.2.0 soupsieve-2.5 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from gdown import download
download("https://drive.google.com/uc?id=1KKSk9ViSl8CzmTtzaL6S4MwENQfWwSLB", output="./Data/data_diem_thi_DH_2023.csv")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KKSk9ViSl8CzmTtzaL6S4MwENQfWwSLB
# To: c:\Projects\MMC_DataScience\Module_02\Projects\Data\data_diem_thi_DH_2023.csv
# 100%|██████████| 40.5M/40.5M [00:02<00:00, 19.7MB/s]
# './Data/data_diem_thi_DH_2023.csv'

# %% [markdown]
# Ta đọc dữ liệu và kiểm tra xem đã có dữ liệu chưa

# %%
# Đọc dữ liệu từ file CSV
df = pd.read_csv("./data/data_diem_thi_DH_2023.csv", sep=",", dtype=str)
df.head()
# Out:
#         sbd toan ngu_van ngoai_ngu vat_li hoa_hoc sinh_hoc lich_su dia_li  \
# 0  01000001  8.4     8.5       9.2    NaN     NaN      NaN    6.75    6.0
# 1  01000002  7.2     8.5       9.2    NaN     NaN      NaN    8.75    6.5
# 2  01000003  NaN     6.5       NaN    NaN     NaN      NaN    9.25    7.5
# 3  01000004  7.8    8.25       7.8    NaN     NaN      NaN     4.5   6.25
# 4  01000005  7.2     8.0       7.8    NaN     NaN      NaN    4.75   6.75
#
#    gdcd ma_ngoai_ngu
# 0   9.0           N1
# 1   8.5           N1
# 2   NaN          NaN
# 3  8.25           N1
# 4  8.25           N1

# %% [markdown]
# Vì trường ma_ngoai_ngu đa phần là N1 nên ta sẽ không sử dụng trong việc phân tích.

# %%
df.drop('ma_ngoai_ngu', axis=1, inplace=True)
df.head()
# Out:
#         sbd toan ngu_van ngoai_ngu vat_li hoa_hoc sinh_hoc lich_su dia_li  \
# 0  01000001  8.4     8.5       9.2    NaN     NaN      NaN    6.75    6.0
# 1  01000002  7.2     8.5       9.2    NaN     NaN      NaN    8.75    6.5
# 2  01000003  NaN     6.5       NaN    NaN     NaN      NaN    9.25    7.5
# 3  01000004  7.8    8.25       7.8    NaN     NaN      NaN     4.5   6.25
# 4  01000005  7.2     8.0       7.8    NaN     NaN      NaN    4.75   6.75
#
#    gdcd
# 0   9.0
# 1   8.5
# 2   NaN
# 3  8.25
# 4  8.25

# %% [markdown]
# ### Phân tích theo tỉnh thành:

# %% [markdown]
# #### Điểm trung bình các môn theo tỉnh thành

# %% [markdown]
# Trước hết, ta sẽ dựa vào SBD để tạo thêm một cột tỉnh thành trong DataFrame.

# %%
df['Tỉnh thành'] = df['sbd'].str[:2].map({v[:2]: k for k, v in cities.items()})

# %%
# Kiểm tra lại
df.head()
# Out:
#         sbd toan ngu_van ngoai_ngu vat_li hoa_hoc sinh_hoc lich_su dia_li  \
# 0  01000001  8.4     8.5       9.2    NaN     NaN      NaN    6.75    6.0
# 1  01000002  7.2     8.5       9.2    NaN     NaN      NaN    8.75    6.5
# 2  01000003  NaN     6.5       NaN    NaN     NaN      NaN    9.25    7.5
# 3  01000004  7.8    8.25       7.8    NaN     NaN      NaN     4.5   6.25
# 4  01000005  7.2     8.0       7.8    NaN     NaN      NaN    4.75   6.75
#
#    gdcd      Tỉnh thành trung_binh_tat_ca_mon
# 0   9.0  Sở GDĐT Hà Nội                   8.5
# 1   8.5  Sở GDĐT Hà Nội                   8.5
# 2   NaN  Sở GDĐT Hà Nội                   6.5
# 3  8.25  Sở GDĐT Hà Nội                  8.25
# 4  8.25  Sở GDĐT Hà Nội                   8.0

# %%
# Tạo cột mới là trung bình của tất cả các môn

df['trung_binh_tat_ca_mon'] = df[['toan', 'ngu_van', 'ngoai_ngu', 'vat_li', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_li', 'gdcd']].mean(axis=1)

# Tính trung bình điểm của tất cả các môn theo mỗi tỉnh thành
diem_trung_binh_tat_ca_mon_theo_tinh = df.groupby('Tỉnh thành')['trung_binh_tat_ca_mon'].mean()

# In ra kết quả
print(diem_trung_binh_tat_ca_mon_theo_tinh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Tạo cột mới là trung bình của tất cả các môn
# ----> 3 df['trung_binh_tat_ca_mon'] = df[['toan', 'ngu_van', 'ngoai_ngu', 'vat_li', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_li', 'gdcd']].mean(axis=1)
#       5 # Tính trung bình điểm của tất cả các môn theo mỗi tỉnh thành
#       6 diem_trung_binh_tat_ca_mon_theo_tinh = df.groupby('Tỉnh thành')['trung_binh_tat_ca_mon'].mean()
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\frame.py:11338, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11330 @doc(make_doc("mean", ndim=2))
#   11331 def mean(
#   11332     self,
#    (...)
#   11336     **kwargs,
#   11337 ):
# > 11338     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11339     if isinstance(result, Series):
#   11340         result = result.__finalize__(self, method="mean")
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11931 nv.validate_func(name, (), kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\frame.py:11207, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11203     df = df.T
#   11205 # After possibly _get_data and transposing, we are now in the
#   11206 #  simple case where we can use BlockManager.reduce
# > 11207 res = df._mgr.reduce(blk_func)
#   11208 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11209 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\internals\managers.py:1459, in BlockManager.reduce(self, func)
#    1457 res_blocks: list[Block] = []
#    1458 for blk in self.blocks:
# -> 1459     nbs = blk.reduce(func)
#    1460     res_blocks.extend(nbs)
#    1462 index = Index([None])  # placeholder
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\internals\blocks.py:377, in Block.reduce(self, func)
#     371 @final
#     372 def reduce(self, func) -> list[Block]:
#     373     # We will apply the function and reshape the result into a single-row
#     374     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     375     assert self.ndim == 2
# --> 377     result = func(self.values)
#     379     if self.values.ndim == 1:
#     380         res_values = result
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\frame.py:11139, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11137         return np.array([result])
#   11138 else:
# > 11139     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Projects\MMC_DataScience\.conda\lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Vẽ biểu đồ điểm trung bình của mỗi môn học ở mỗi tỉnh thành
diem_trung_binh_tat_ca_mon_theo_tinh.plot(kind='bar', figsize=(15, 5))
plt.title("Điểm trung bình của mỗi môn học ở mỗi tỉnh thành")
plt.ylabel("Điểm trung bình")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Bạn cũng có thể sắp xếp biểu đồ theo giá trị từ lớn tới nhỏ

# %%
# Sắp xếp theo giá trị giảm dần

diem_trung_binh_tat_ca_mon_theo_tinh.sort_values(ascending=False, inplace=True)
diem_trung_binh_tat_ca_mon_theo_tinh.plot(kind='bar', figsize=(15, 5))
plt.title("Điểm trung bình của mỗi môn học ở mỗi tỉnh thành")
plt.ylabel("Điểm trung bình")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Như vậy ta có thể thấy TOP 5 tỉnh có điểm trung bình cao nhất là Vĩnh Phúc, Bình Dương, Nam Định, Bắc Ninh và Hải Phòng.

# %% [markdown]
# **Được rồi, giờ là phần công việc của bạn :)))**

# %% [markdown]
# Hãy hoàn thiện các yêu cầu còn lại

# %% [markdown]
# #### Điểm trung bình từng môn theo 1 tỉnh bất kỳ

# %% [markdown]
# * Yêu cầu: So sánh điểm trung bình của mỗi môn học theo từng tỉnh thành.
#  Sau đó đưa ra phân tích: Xác định tỉnh thành có điểm trung bình cao nhất, thấp nhất ở mỗi môn học.

# %%
df.where(df["Tỉnh thành"] == "Sở GDĐT Hà Nội")
# Out:
#               sbd toan ngu_van ngoai_ngu vat_li hoa_hoc sinh_hoc lich_su  \
# 0        01000001  8.4     8.5       9.2    NaN     NaN      NaN    6.75
# 1        01000002  7.2     8.5       9.2    NaN     NaN      NaN    8.75
# 2        01000003  NaN     6.5       NaN    NaN     NaN      NaN    9.25
# 3        01000004  7.8    8.25       7.8    NaN     NaN      NaN     4.5
# 4        01000005  7.2     8.0       7.8    NaN     NaN      NaN    4.75
# ...           ...  ...     ...       ...    ...     ...      ...     ...
# 1022055       NaN  NaN     NaN       NaN    NaN     NaN      NaN     NaN
# 1022056       NaN  NaN     NaN       NaN    NaN     NaN      NaN     NaN
# 1022057       NaN  NaN     NaN       NaN    NaN     NaN      NaN     NaN
# 1022058       NaN  NaN     NaN       NaN    NaN     NaN      NaN     NaN
# 1022059       NaN  NaN     NaN       NaN    NaN     NaN      NaN     NaN
#
#         dia_li  gdcd      Tỉnh thành trung_binh_tat_ca_mon
# 0          6.0   9.0  Sở GDĐT Hà Nội                   8.5
# 1          6.5   8.5  Sở GDĐT Hà Nội                   8.5
# 2          7.5   NaN  Sở GDĐT Hà Nội                   6.5
# 3         6.25  8.25  Sở GDĐT Hà Nội                  8.25
# 4         6.75  8.25  Sở GDĐT Hà Nội                   8.0
# ...        ...   ...             ...                   ...
# 1022055    NaN   NaN             NaN                   NaN
# 1022056    NaN   NaN             NaN                   NaN
# 1022057    NaN   NaN             NaN                   NaN
# 1022058    NaN   NaN             NaN                   NaN
# 1022059    NaN   NaN             NaN                   NaN
#
# [1022060 rows x 12 columns]

# %% [markdown]
# #### Hiển thị mối liên hệ giữa điểm số của 2 môn học

# %% [markdown]
# Yêu cầu: Hiển thị mối liên hệ giữa điểm số của 2 môn học. Từ đó phân tích: Xác định mối tương quan giữa điểm số của các môn học, tìm hiểu xem điểm số môn này có ảnh hưởng đến điểm số môn kia hay không.

# %% [markdown]
# Ở đây mình sẽ ví dụ với 2 môn toán và ngữ văn.

# %%
subject1 = "toan"
subject2 = "ngu_van"

# Calculate the correlation coefficient
correlation = df[subject1].astype(float).corr(df[subject2].astype(float))

# Print the correlation coefficient
print(f"Correlation between {subject1} and {subject2}: {correlation}")

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df[subject1].astype(float), df[subject2].astype(float))
plt.xlabel(subject1)
plt.ylabel(subject2)
plt.title(f"Scatter Plot of {subject1} vs. {subject2}")
plt.show()

# Analyze the scatter plot
# - If the points are clustered around a straight line, there is a strong correlation.
# - If the points are scattered randomly, there is no correlation.
# - If the points form a U-shape or an inverted U-shape, there is a non-linear correlation.

# Based on the scatter plot and the correlation coefficient, draw conclusions about the relationship between the two subjects.
if abs(correlation) > 0.7:
    print(
        f"There is a strong {('positive' if correlation > 0 else 'negative')} correlation between {subject1} and {subject2}."
    )
elif abs(correlation) > 0.3:
    print(
        f"There is a moderate {('positive' if correlation > 0 else 'negative')} correlation between {subject1} and {subject2}."
    )
else:
    print(f"There is no significant correlation between {subject1} and {subject2}.")
# Out:
# Correlation between toan and ngu_van: 0.4586158220020488
# There is a moderate positive correlation between toan and ngu_van.

# %% [markdown]
# Theo biểu đồ là ta thấy ngay kết quả có sự tương quan giữa 2 môn này. Vậy từ đoạn code trên, sử dụng biểu đồ Scatter xem có sự tương quan nào giữa môn vật lý và địa lý hay không?

# %%
subject1 = "vat_li"
subject2 = "dia_li"

# Calculate the correlation coefficient
correlation = df[subject1].astype(float).corr(df[subject2].astype(float))

# Print the correlation coefficient
print(f"Correlation between {subject1} and {subject2}: {correlation}")

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df[subject1].astype(float), df[subject2].astype(float))
plt.xlabel(subject1)
plt.ylabel(subject2)
plt.title(f"Scatter Plot of {subject1} vs. {subject2}")
plt.show()

# Analyze the scatter plot
# - If the points are clustered around a straight line, there is a strong correlation.
# - If the points are scattered randomly, there is no correlation.
# - If the points form a U-shape or an inverted U-shape, there is a non-linear correlation.

# Based on the scatter plot and the correlation coefficient, draw conclusions about the relationship between the two subjects.
if abs(correlation) > 0.7:
    print(
        f"There is a strong {('positive' if correlation > 0 else 'negative')} correlation between {subject1} and {subject2}."
    )
elif abs(correlation) > 0.3:
    print(
        f"There is a moderate {('positive' if correlation > 0 else 'negative')} correlation between {subject1} and {subject2}."
    )
else:
    print(f"There is no significant correlation between {subject1} and {subject2}.")
# Out:
# Correlation between vat_li and dia_li: nan
# There is no significant correlation between vat_li and dia_li.

# %% [markdown]
# ### Phân tích chung về điểm số

# %% [markdown]
# Yêu cầu:
# * **Biểu đồ cột:** Hiển thị điểm trung bình của mỗi môn học (Toán, Ngữ Văn, Ngoại ngữ,...) trên toàn bộ dữ liệu.
#     * **Phân tích:** So sánh điểm trung bình của các môn học, tìm ra môn học có điểm trung bình cao nhất, thấp nhất.
# * **Biểu đồ phân bố:** Hiển thị phân bố điểm số của mỗi môn học (sử dụng histogram hoặc box plot).
#     * **Phân tích:** Nhận biết điểm số tập trung nhiều nhất, độ lệch của điểm số, điểm số cực trị.

# %% [markdown]
# ### Nâng cao

# %% [markdown]
# Hãy thử tìm hiểu và đưa ra 2 ý tưởng phân tích từ dữ liệu trên. Ngoài ra, hãy thử lưu dữ liệu crawl về được sau đó lưu vào database xem. Chắc chắn là sẽ mất thêm thời gian để bạn học đó :))))

# %% [markdown]
# # Tổng kết

# %% [markdown]
# Phù ! Phân tích này có vẻ mệt nhỉ :v
# Project này chúng ta đã cùng đi crawl dữ liệu và phân tích về điểm thi đại học. Sẽ có rất nhiều ý tưởng chờ mọi người hiện thực hóa.
#
# Rất mong cả nhà MMC của mình sẽ hoàn thành được Project nho nhỏ này. Soạn xong bài này cũng đúng 2 ngày kỳ công. Vậy nên là cả nhà đừng quên làm đủ và nộp nha. yêu cả nha :D
