# %% [markdown]
# ```
# - Giới thiệu về Pandas, Series, DataFrames
# - Cách đọc dữ liệu trong Pandas Python- Cách xuất dữ liệu từ Pandas DataFrame
# - Cách tạo ra dữ liệu test
# - Cách xem và kiểm tra dữ liệu
# - Trích xuất một phần dữ liệu trong Pandas DataFrame
# ```

# %% [markdown]
# ## Giới thiệu về Pandas, Series, DataFrames

# %% [markdown]
# ### Pandas

# %% [markdown]
# Pandas là một thư viện mã nguồn mở được xây dựng dựa trên NumPy, sử dụng thao tác và phân tích dữ liệu, được thiết kế để cho phép bạn làm việc với dữ liệu được gắn nhãn hoặc quan hệ theo cách trực quan hơn
#
# * Có thể xử lý tập dữ liệu khác nhau về định dạng: chuỗi thời gian, bảng không đồng nhất, ma trận dữ liệu
# Khả năng import dữ liệu từ nhiều nguồn khác nhau như CSV, DB/SQL
# * Có thể xử lý vô số phép toán cho tập dữ liệu: subsetting, slicing, filtering, merging, groupBy, re-ordering, and re-shaping,..
# * Xử lý dữ liệu mất mát theo ý người dùng mong muốn: bỏ qua hoặc chuyển sang 0
# * Xử lý, phân tích dữ liệu tốt như mô hình hoá và thống kê
# * Tích hợp tốt với các thư viện khác của python
# * Cung cấp hiệu suất tốt
#
# Để cài đặt pandas nếu bạn có Anaconda chỉ cần gõ `conda install pandas` hoặc sử dụng tools pip `pip install pandas`.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sau khi cài đặt xong, trong Python, chúng ta cần khai báo `import pandas` để có thể bắt đầu sử dụng các hàm của pandas. Vì pandas là thư viện được sử dụng thường xuyên nên nó thường được khai báo gọn lại thành pd `import pandas as pd` pd có thể thay thế bằng các từ khác, tuy nhiên bạn nên đặt là pd vì các tài liệu hướng dẫn đều ngầm quy ước như thế

# %%
import pandas as pd

# %% [markdown]
# Pandas có ba cấu trúc dữ liệu và nó được xây dựng dựa trên thư viện Numpy vậy nên chúng hoạt động rất nhanh và hiệu quả: `Series, DataFrame, Panel`. Trong đó Panel là mảng 3 chiều. Panel thì không được sử dụng rãi như như Series hay DataFrame và nó cũng không dễ hiển thị hay trừu tượng hoá như màn một chiều và hai chiều, nên trong bài học này chỉ giới thiệu **Series** và **DataFrame**
#
# Đại khái hiểu là Pandas có 2 cấu trúc dữ liệu cơ bản là:
# * Series (1 chiều)
# * DataFrame (2 chiều)).

# %% [markdown]
# ### Series

# %% [markdown]
# Series là mảng một chiều giống như mảng Numpy, hay như một cột của một bảng, nhưng nó bao gồm thêm một bảng đánh label. Series có thể được khởi tạo thông qua NumPy, kiểu Dict hoặc các dữ liệu vô hướng bình thường

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Đặc điểm</th>
#       <th>Series (Pandas)</th>
#       <th>NumPy Array</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Kiểu dữ liệu</td>
#       <td>Hỗ trợ nhiều kiểu dữ liệu khác nhau trong cùng một Series (object dtype). Có thể ép kiểu dữ liệu cho toàn bộ Series.</td>
#       <td>Tất cả các phần tử phải cùng kiểu dữ liệu.</td>
#     </tr>
#     <tr>
#       <td>Chỉ mục</td>
#       <td>Có chỉ mục rõ ràng (có thể là số nguyên, chuỗi, datetime,...). Cho phép truy cập và thao tác dữ liệu dựa trên chỉ mục.</td>
#       <td>Chỉ mục ngầm định là số nguyên (0, 1, 2,...).</td>
#     </tr>
#     <tr>
#       <td>Tên cột</td>
#       <td>Có thể có tên cột.</td>
#       <td>Không có tên cột.</td>
#     </tr>
#     <tr>
#       <td>Chiều</td>
#       <td>1 chiều</td>
#       <td>Có thể là nhiều chiều.</td>
#     </tr>
#     <tr>
#       <td>Thao tác dữ liệu</td>
#       <td>Cung cấp nhiều hàm và phương thức mạnh mẽ để xử lý và phân tích dữ liệu (ví dụ: `fillna`, `groupby`, `rolling`,...).</td>
#       <td>Cung cấp các hàm toán học và logic cơ bản để thao tác mảng (ví dụ: `sum`, `mean`, `std`,...).</td>
#     </tr>
#     <tr>
#       <td>Tốc độ</td>
#       <td>Thường chậm hơn NumPy do tính linh hoạt về kiểu dữ liệu và chỉ mục.</td>
#       <td>Tối ưu hóa cho tốc độ xử lý dữ liệu, đặc biệt là với các mảng lớn.</td>
#     </tr>
#     <tr>
#       <td>Bộ nhớ</td>
#       <td>Có thể tốn nhiều bộ nhớ hơn NumPy do tính năng chỉ mục rõ ràng.</td>
#       <td>Sử dụng bộ nhớ hiệu quả hơn.</td>
#     </tr>
#     <tr>
#       <td>Ứng dụng</td>
#       <td>Phù hợp cho dữ liệu dạng bảng, chuỗi thời gian, phân tích dữ liệu, thống kê.</td>
#       <td>Phù hợp cho tính toán khoa học, đại số tuyến tính, xử lý hình ảnh.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Series có thể được tạo bằng cách sử dụng hàm tạo sau `pandas.Series( data, index, dtype, copy)`

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th></th>
# <th>Mô tả</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>data</strong></td>
# <td>có nhiều dạng khác nhau như ndarray (mảng n chiều), list, constants</td>
# </tr>
# <tr>
# <td><strong>index</strong></td>
# <td>Các giá trị index phải là duy nhất và có thể là hash có cùng độ dài với dữ liệu Mặc định <code>np.arrange (n)</code> nếu không có chỉ mục nào được thông qua</td>
# </tr>
# <tr>
# <td><strong>dtype</strong></td>
# <td>loại dữ liệu. Nếu không có, kiểu dữ liệu sẽ được suy ra</td>
# </tr>
# <tr>
# <td><strong>copy</strong></td>
# <td>Sao chép dữ liệu, mặc định là false</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Một Series có thể được tạo bằng các đầu vào khác nhau như: Array, Dict, Scalar value hoặc constant

# %% [markdown]
# #### Tạo một series rỗng:

# %%
#Khai báo thư viện pandas và khai báo nó là pd
import pandas as pd

s = pd.Series()
print(s)
# Out:
# Series([], dtype: object)

# %% [markdown]
# Khi chúng ta không truyền index, thì mặc định nó sẽ đánh từ 0 đến len(data)-1

# %%
#Khai báo thư viện pandas và khai báo nó là pd
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %% [markdown]
# #### Tạo một Series từ dict

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = {'a' : 0, 'b' : 1, 'c' : 2}
s = pd.Series(data,index=['b','c','d','a'], dtype = np.int64)
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %% [markdown]
# Chú ý: Thứ tự của index được duy trì và phần tử bị thiếu được lấp đầy bằng NaN (Không phải là số)

# %% [markdown]
# #### Truy cập dữ liệu từ Series với Position

# %% [markdown]
# Dữ liệu trong series có thể được truy cập tương tự như dữ liệu trong một ndarray.

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
s['d'] # Lấy phần tử đầu tiên
# Out:
# 4

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
s[-10:]
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# #### Truy xuất dữ liệu bằng Label (Index)

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])

# Lấy một phần tử
s['a'] # Output: 1
# Out:
# 1

# %% [markdown]
# Ta cũng có thể truy xuất nhiều phần tử bằng cách sử dụng danh sách các giá trị index label

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['STT','Ten','Email','Luong','Co ny chua'])

# Lấy nhiều phần tử
s[['STT','Ten','Co ny chua']]
# Out:
# STT           1
# Ten           2
# Co ny chua    5
# dtype: int64

# %%
# Nếu label không tồn tại, thì sẽ ném exception
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])

# Lấy một phần tử
s['f']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### DataFrame

# %% [markdown]
# Một Data frame là một cấu trúc dữ liệu 2 chiều, dữ liệu được sắp xếp theo kiểu bảng trong các hàng và cột có các đặc trưng sau:
#
# * Các cột dữ liệu là các kiểu không đồng nhất: float64, int, bool, …
# * Kích thước table có thể thay đổi: các cột có thể thêm hoặc xoá đi
# * Các trục được dán nhãn (hàng và cột)
# * Có thể thực hiện các phép toán số học trên các hàng và cột*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Một DataFrame có thể được tạo bằng cách sử dụng hàm tạo sau `pandas.DataFrame( data, index, columns, dtype, copy)`

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th></th>
# <th>Mô tả</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>data</strong></td>
# <td>dữ liệu có nhiều dạng khác nhau như ndarray, series, map, lists, dict, constants hoặc một DataFrame khác</td>
# </tr>
# <tr>
# <td><strong>index</strong></td>
# <td>Đối với các row labels, <strong>Index</strong> được sử dụng cho resulting frame là Mặc định tùy chọn <code>np.arrange (n)</code> nếu không có <strong>index</strong> nào được thông qua</td>
# </tr>
# <tr>
# <td><strong>columns</strong></td>
# <td>Đối với các column  labels. cú pháp mặc định tùy chọn là - <code>np.arrange(n)</code>   ,Điều này chỉ đúng nếu không có <strong>index</strong> nào được thông qua</td>
# </tr>
# <tr>
# <td><strong>dtype</strong></td>
# <td>Kiểu dữ liệu của từng cột</td>
# </tr>
# <tr>
# <td><strong>copy</strong></td>
# <td>Sao chép dữ liệu, mặc định là false</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# #### Tạo một DataFrame rỗng

# %%
#import the pandas library and aliasing as pd
import pandas as pd
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Tạo một DataFrame từ Lists

# %%
import pandas as pd
data = [1,2,3,4,5]
df = pd.DataFrame(data)

df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# Tạo từ một danh sach các lists

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])

df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %% [markdown]
# #### Tạo một DataFrame từ Dict của ndarrays / Lists

# %% [markdown]
# Tất cả các ndarrays phải có cùng độ dài. Nếu index được thông qua, thì độ dài của index sẽ bằng với độ dài của mảng
#
# Nếu không có index nào được truyền, thì theo mặc định, index sẽ là range (n), trong đó n là độ dài mảng

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)

df
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %% [markdown]
# Chú thích: Quan sát các giá trị 0,1,2,3. Chúng là index mặc định được gán cho từng row sử dụng hàm range(n).

# %% [markdown]
# Ta cũng có thể tạo một DataFrame được lập index bằng cách sử dụng các arrays

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])

df
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %% [markdown]
# #### Tạo một DataFrame từ một danh sách của Dicts

# %% [markdown]
# Danh sách Dictionaries có thể được chuyển qua dưới dạng dữ liệu đầu vào để tạo DataFrame. Các keys của Dictionaries theo mặc định được lấy làm tên cột
#
# Ví dụ sau đây cho thấy cách tạo DataFrame bằng cách truyền một list các dictionaries (Chú thích: NaN (Not a Number) được thêm vào các khu vực bị thiếu)

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)

df
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# Tạo DataFrame bằng cách chuyển danh sách dictionaries và các index hàng

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data, index=['first', 'second'])

df
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %% [markdown]
# #### Tạo một DataFrame từ Dict của Series

# %% [markdown]
# Dictionary của Series có thể được thông qua để tạo thành một DataFrame. Index là sự kết hợp của tất cả các index được thông qua

# %%
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# Tạo từ một danh sach các lists

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])

df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %% [markdown]
# Ta có thể thay đổi tham số tuổi thành float

# %%
import pandas as pd
data = [['Alex', 10], ['Bob', 12], ['Clarke', 13]]
df = pd.DataFrame(data, columns=['Name', 'Age'])
df['Age'] = df['Age'].astype(float)

df
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0

# %% [markdown]
# #### Cách thêm cột trong DataFrame

# %%
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

# Adding a new column to an existing DataFrame object with column label by passing new series

print ("Adding a new column by passing as Series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
df

print ("Adding a new column using the existing columns in DataFrame:")
df['four']=df['one']+df['three']

df
# Out:
# Adding a new column by passing as Series:
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %% [markdown]
# Cách 1: Tạo cột mới bằng cách gán giá trị cho tên cột mới.

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Thêm cột 'C' với giá trị 7 cho tất cả các dòng
df['C'] = 7

df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  7
# 2  3  6  7

# %% [markdown]
# Cách 2: Sử dụng hàm assign().

# %%
df = df.assign(D = [10, 20, 30])

df
# Out:
#    A   E   D
# 0  1  10  10
# 1  2  20  20
# 2  3  30  30

# %% [markdown]
# Cách 3: Sử dụng hàm insert() để thêm cột vào vị trí cụ thể.

# %%
# Insert a new column at index 1
df.insert(1, 'F', [10, 20, 30])

print(df)
# Out:
#    A   F   E  B  C
# 0  1  10  10  4  7
# 1  2  20  20  5  7
# 2  3  30  30  6  7

# %% [markdown]
# #### Cách sửa cột trong DataFrame

# %% [markdown]
# Cách 1: Gán giá trị mới cho cột

# %%
df['B'] = df['B'] * 2

df
# Out:
#    A   F   E   B  C
# 0  1  10  10   8  7
# 1  2  20  20  10  7
# 2  3  30  30  12  7

# %% [markdown]
# Cách 2: Áp dụng hàm cho cột.

# %%
df['A'] = df['A'].apply(lambda x: x + 1)
df
# Out:
#    A   E   B  C   D
# 0  2  11   8  7  10
# 1  3  22  10  7  20
# 2  4  33  12  7  30

# %% [markdown]
# Lưu ý: Nếu bạn chưa nắm rõ về Lamda. Tham khảo [tại đây](https://colab.research.google.com/drive/1V8m8OP7WPGU9EltnLq3z1uzx-bTDOe1B?usp=sharing)

# %% [markdown]
# #### Cách xóa cột trong DataFrame

# %% [markdown]
# Cách 1: Sử dụng del

# %%
del df['C']

df
# Out:
#     F   E   B
# 0  10  10   8
# 1  20  20  10
# 2  30  30  12

# %% [markdown]
# Cách 2: Sử dụng hàm pop()

# %%
df.pop('E')

df
# Out:
#     F   B
# 0  10   8
# 1  20  10
# 2  30  12

# %% [markdown]
# Cách 3: Sử dụng hàm drop()

# %%
df = df.drop(2, axis=0)

df
# Out:
#     F
# 0  10

# %% [markdown]
# **Lưu ý:**
# * Tham số axis=1 trong hàm drop() chỉ định rằng bạn muốn xóa cột (axis=0 là xóa dòng).
# * Hàm pop() trả về giá trị của cột bị xóa.
# * Cần cẩn thận khi sử dụng del vì nó sẽ xóa cột vĩnh viễn khỏi DataFrame

# %%
# Ví dụ
import pandas as pd

# Khởi tạo DataFrame
data = {'Tên': ['An', 'Bình', 'Cường'],
        'Tuổi': [20, 25, 30],
        'Điểm': [8, 9, 7]}
df = pd.DataFrame(data)


print(df)
# Out:
#      Tên  Tuổi  Điểm
# 0     An    20     8
# 1   Bình    25     9
# 2  Cường    30     7

# %%
# Thêm cột 'Lớp'
df['Lớp'] = ['A', 'B', 'C']
df
# Out:
#      Tên  Tuổi  Điểm Lớp
# 0     An    20     8   A
# 1   Bình    25     9   B
# 2  Cường    30     7   C

# %%
# Sửa cột 'Tuổi', tăng tuổi của mỗi người lên 1
df['Tuổi'] = df['Tuổi'] + 1
df
# Out:
#      Tên  Tuổi  Điểm Lớp
# 0     An    22     8   A
# 1   Bình    27     9   B
# 2  Cường    32     7   C

# %%
# Xóa cột 'Điểm'
df = df.drop('Điểm', axis=1)

# %%
df
# Out:
#      Tên  Tuổi Lớp
# 0     An    22   A
# 1   Bình    27   B
# 2  Cường    32   C

# %%
df.drop(2, axis=0)
# Out:
#     Tên  Tuổi Lớp
# 0    An    22   A
# 1  Bình    27   B
