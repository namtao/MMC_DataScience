# %%
import re
import numpy as np
import sys

# filename = input("Nhập đường dẫn của tệp: ")
filenames = [
    r"Data Files\class1.txt",
    r"Data Files\class2.txt",
    r"Data Files\class3.txt",
    r"Data Files\class4.txt",
    r"Data Files\class5.txt",
    r"Data Files\class6.txt",
    r"Data Files\class7.txt",
    r"Data Files\class8.txt",
]
# filename = r"Data Files\class1.txt"

for filename in filenames:
    answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D"
    lst_answer = answer_key.split(",")

    sum_count = 0
    err_count = 0
    dic_score = {}
    hight_score = 0
    dic_pass = {}
    dic_failed = {}

    try:
        f = open(filename, "r")
    except Exception as e:
        print(f"Không tìm thấy tệp, vui lòng kiểm tra lại!")
        sys.exit()

    with f:
        print("Mở file thành công!")
        print(f"Xử lý file: {filename}")
        for line in f:
            elements = line.strip().split(",")
            # kiểm tra hợp lệ của dòng
            if not (len(elements) == 26 and re.match("^N\d{8}", str(elements[0]))):
                err_count += 1
                print(f"{elements[0]} không hợp lệ!")
            else:
                for index, value in enumerate(elements):
                    # index = 0 là mã của sinh vien
                    if index == 0:
                        dic_score[value] = 0
                        continue

                    # câu trả lời bị bỏ qua
                    if value is None or value == "":
                        dic_score[elements[0]] += 0

                        if str(index) in dic_pass.keys():
                            dic_pass[str(index)] += 1
                        else:
                            dic_pass[str(index)] = 1

                    # câu trả lời đúng
                    elif value == lst_answer[index - 1]:
                        dic_score[elements[0]] += 4
                    # câu trả lời sai
                    elif value != lst_answer[index - 1]:
                        dic_score[elements[0]] -= 1

                        if str(index) in dic_failed.keys():
                            dic_failed[str(index)] += 1
                        else:
                            dic_failed[str(index)] = 1
            sum_count += 1

    print(f"\nTổng số dòng là: {sum_count}\nTổng số dòng lỗi là: {err_count}")
    dic_score_sort = sorted(dic_score.items(), key=lambda x: x[1], reverse=True)

    for k, v in dic_score.items():
        if v > 80:
            hight_score += 1

    print(f"Số lượng học sinh đạt điểm cao là :{hight_score}")
    print(f"Điểm trung bình là: {np.mean(list(dic_score.values()))}")
    print(f"Điểm cao nhất là {dic_score_sort[0][1]}")
    print(f"Điểm thấp nhất là {dic_score_sort[-1][1]}")
    print(f"Miền giá trị là {dic_score_sort[0][1] - dic_score_sort[-1][1]}")
    print(f"Giá trị trung vị là: {np.median(list(dic_score.values()))}")

    # các câu hỏi bị bỏ qua nhiều nhất theo thứ tự:
    # số thứ tự câu hỏi - số lượng học sinh bỏ qua - tỷ lệ bị bỏ qua

    # lấy giá trị max
    max_pass_value = sorted(dic_pass.items(), key=lambda x: x[1], reverse=True)[0][1]
    max_failed_value = sorted(dic_failed.items(), key=lambda x: x[1], reverse=True)[0][1]

    print(f"Giá trị - Số lượng - Tỷ lệ bị bỏ qua là: ")
    for k, v in dict(sorted(dic_pass.items(), key=lambda x: int(x[0]))).items():
        if v == max_pass_value:
            print(f"{k} - {v} - {round(v/sum_count, 3)}")

    print(f"Giá trị - Số lượng - Tỷ lệ bị sai là: ")
    for k, v in dict(sorted(dic_failed.items(), key=lambda x: int(x[0]))).items():
        if v == max_failed_value:
            print(f"{k} - {v} - {round(v/sum_count, 3)}")


    # tạo file kết quả
    file_name_result = (filename.split("\\")[-1]).split(".")[0] + "_grades.txt"
    with open(file_name_result, "w+") as f:
        for k, v in dict(sorted(dic_score.items())).items():
            f.write(f"{k}, {v}\n")
# Out:
# Mở file thành công!
# Xử lý file Data Files\class1.txt
#
# Tổng số dòng là: 20
# Tổng số dòng lỗi là: 0
# Số lượng học sinh đạt điểm cao là :6
# Điểm trung bình là: 75.6
# Điểm cao nhất là 91
# Điểm thấp nhất là 59
# Miền giá trị là 32
# Giá trị trung vị là: 73.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 3 - 4 - 0.2
# 5 - 4 - 0.2
# 23 - 4 - 0.2
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 10 - 4 - 0.2
# 14 - 4 - 0.2
# 16 - 4 - 0.2
# 19 - 4 - 0.2
# 22 - 4 - 0.2
# Mở file thành công!
# Xử lý file Data Files\class2.txt
# N00000023 không hợp lệ!
# N0000002 không hợp lệ!
# NA0000027 không hợp lệ!
# N00000035 không hợp lệ!
#
# Tổng số dòng là: 25
# Tổng số dòng lỗi là: 4
# Số lượng học sinh đạt điểm cao là :7
# Điểm trung bình là: 78.0
# Điểm cao nhất là 100
# Điểm thấp nhất là 66
# Miền giá trị là 34
# Giá trị trung vị là: 76.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 22 - 6 - 0.24
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 18 - 5 - 0.2
# Mở file thành công!
# Xử lý file Data Files\class3.txt
#
# Tổng số dòng là: 100
# Tổng số dòng lỗi là: 0
# Số lượng học sinh đạt điểm cao là :38
# Điểm trung bình là: 76.24
# Điểm cao nhất là 96
# Điểm thấp nhất là 56
# Miền giá trị là 40
# Giá trị trung vị là: 77.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 4 - 15 - 0.15
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 18 - 17 - 0.17
# Mở file thành công!
# Xử lý file Data Files\class4.txt
# N00000616 không hợp lệ!
# N0000062 không hợp lệ!
# N000008A8 không hợp lệ!
# N00000638 không hợp lệ!
#
# Tổng số dòng là: 495
# Tổng số dòng lỗi là: 4
# Số lượng học sinh đạt điểm cao là :166
# Điểm trung bình là: 75.76374745417515
# Điểm cao nhất là 100
# Điểm thấp nhất là 44
# Miền giá trị là 56
# Giá trị trung vị là: 77.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 3 - 66 - 0.133
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 9 - 66 - 0.133
# Mở file thành công!
# Xử lý file Data Files\class5.txt
#
# Tổng số dòng là: 1000
# Tổng số dòng lỗi là: 0
# Số lượng học sinh đạt điểm cao là :346
# Điểm trung bình là: 75.604
# Điểm cao nhất là 100
# Điểm thấp nhất là 40
# Miền giá trị là 60
# Giá trị trung vị là: 77.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 6 - 117 - 0.117
# 23 - 117 - 0.117
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 12 - 130 - 0.13
# Mở file thành công!
# Xử lý file Data Files\class6.txt
# N00001648 không hợp lệ!
#
# Tổng số dòng là: 301
# Tổng số dòng lỗi là: 1
# Số lượng học sinh đạt điểm cao là :106
# Điểm trung bình là: 75.9
# Điểm cao nhất là 100
# Điểm thấp nhất là 49
# Miền giá trị là 51
# Giá trị trung vị là: 77.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 17 - 43 - 0.143
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 23 - 42 - 0.14
# Mở file thành công!
# Xử lý file Data Files\class7.txt
# N0000194 không hợp lệ!
# N00001966 không hợp lệ!
# N00001974 không hợp lệ!
# N0000198O không hợp lệ!
# F00000000 không hợp lệ!
# N00002023 không hợp lệ!
# N00002034 không hợp lệ!
#
# Tổng số dòng là: 200
# Tổng số dòng lỗi là: 7
# Số lượng học sinh đạt điểm cao là :59
# Điểm trung bình là: 74.84974093264249
# Điểm cao nhất là 100
# Điểm thấp nhất là 47
# Miền giá trị là 53
# Giá trị trung vị là: 75.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 4 - 28 - 0.14
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 7 - 32 - 0.16
# Mở file thành công!
# Xử lý file Data Files\class8.txt
#
# Tổng số dòng là: 49
# Tổng số dòng lỗi là: 0
# Số lượng học sinh đạt điểm cao là :17
# Điểm trung bình là: 76.6734693877551
# Điểm cao nhất là 92
# Điểm thấp nhất là 59
# Miền giá trị là 33
# Giá trị trung vị là: 77.0
# Giá trị - Số lượng - Tỷ lệ bị bỏ qua là:
# 4 - 9 - 0.184
# Giá trị - Số lượng - Tỷ lệ bị sai là:
# 4 - 9 - 0.184
# 15 - 9 - 0.184
